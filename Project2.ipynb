# %%
import pandas as pd
dataset1 = pd.read_excel("C:/Users/lenovo/Downloads/dataset_1.xlsx")
print(dataset1)
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %%
dataset1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
dataset1.duplicated().sum()
# Out:
# 0

# %%
df1['dteday'] = pd.to_datetime(dataset1['dteday'])
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB

# %%
dataset1.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# dtype: object

# %%
dataset2 = pd.read_excel("C:/Users/lenovo/Downloads/dataset_2.xlsx")
print(dataset2)
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
plt.figure(figsize=(5, 3))
sns.histplot(dataset1['temp'], kde=True, color='skyblue')
plt.title('Temperature Distribution')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.show()

# Boxplot -  Temperature by Season
plt.figure(figsize=(5, 3))
sns.boxplot(x='season', y='temp', hue= 'season' , data=dataset1, palette='Set2', legend = False )
plt.title('Temperature by Season')
plt.xlabel('Season')
plt.ylabel('Temperature')
plt.show()

# Scatter plot - Hour vs Temperature with Season 
plt.figure(figsize=(5, 3))
sns.scatterplot(x='hr', y='temp', hue='season', data=dataset1, palette='Set1')
plt.title('Hour vs Temperature (by Season)')
plt.xlabel('Hour of Day')
plt.ylabel('Temperature')
plt.legend(title='Season')
plt.show()

# %%
dataset2.isnull().sum()
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
dataset2.dtypes
# Out:
# instant         int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
dataset2.duplicated().sum()
# Out:
# 0

# %%
dataset2.fillna(0, inplace=True)
print(dataset2.isnull().sum())
# Out:
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
clean_dataset2 = pd.read_excel("C:/Users/lenovo/Downloads/cleaned_dataset_2.xlsx")
print(clean_dataset2)
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
clean_dataset2.isnull().sum()
# Out:
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
clean_dataset2.duplicated().sum()
# Out:
# 0

# %%
# temp vs cnt
plt.figure(figsize=(5,3))
sns.regplot(data=clean_dataset2, x='atemp', y='cnt', scatter_kws={'alpha':0.5}, line_kws={'color': 'red'})
plt.title("Temperature (atemp) vs Total Rentals")
plt.xlabel("Normalized Temperature")
plt.ylabel("Total Rentals")
plt.show()

# humidity vs cnt
plt.figure(figsize=(5,3))
sns.regplot(data=clean_dataset2, x='hum', y='cnt', scatter_kws={'alpha':0.5}, line_kws={'color': 'blue'})
plt.title("Humidity vs Total Rentals")
plt.xlabel("Humidity")
plt.ylabel("Total Rentals")
plt.show()

# windspeed vs cnt
plt.figure(figsize=(5,3))
sns.regplot(data=clean_dataset2, x='windspeed', y='cnt', scatter_kws={'alpha':0.5}, line_kws={'color': 'green'})
plt.title("Windspeed vs Total Rentals")
plt.xlabel("Windspeed")
plt.ylabel("Total Rentals")
plt.show()

# %%
print("dataset1 'instant' dtype:", dataset1['instant'].dtype)
print("clean_dataset2 'instant' dtype:", clean_dataset2['instant'].dtype)
# Out:
# dataset1 'instant' dtype: int64
# clean_dataset2 'instant' dtype: int64

# %%
Dataset_A = pd.merge(dataset1, clean_dataset2, on='instant', how='inner')
print(Dataset_A)
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %%
Dataset_A.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
Dataset_A.duplicated().sum()
# Out:
# 0

# %%
Dataset_A.to_excel("merged_file.xlsx", index=False)
